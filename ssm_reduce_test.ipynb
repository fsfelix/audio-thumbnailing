# %%
from muller import audio_thumb_muller
import matplotlib.pyplot as plt
import librosa
# %matplotlib inline

# %%
at = audio_thumb_muller('sun.wav', k = 5)
at.ssm.visualize()
# Out:
# Calculating features...
# Features calculated.
# Calculating SSM...
# SSM calculated.

# %%
print(at.ssm.s.shape)
# Out:
# (797, 797)

# %%
at_50 = audio_thumb_muller('sun.wav', k = 50)
s_50 = at_50.ssm.s
# Out:
# Calculating features.
# Features calculated.
# Calculating SSM.
# SSM calculated.

# %%
at_25 = audio_thumb_muller('sun.wav', k = 25)
s_25 = at_25.ssm.s
# Out:
# Calculating features.
# Features calculated.
# Calculating SSM.
# SSM calculated.

# %%
at_10 = audio_thumb_muller('sun.wav', k = 10)
s_10 = at_10.ssm.s
# Out:
# Calculating features.
# Features calculated.
# Calculating SSM.
# SSM calculated.

# %%
plt.pcolor(s_10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.pcolor(s_5)

# %%
plt.pcolor(s_50)

# %%
s_25[s_25 < 0.2] = 0 
plt.pcolor(s_25)
plt.title('ssm')
plt.colorbar()
