# %% [markdown]
# ## Thumbnail comparando as duas técnicas implementadas

# %%
from cooper_foote import audio_thumb_cf
from muller       import audio_thumb_muller

# %%
muller = audio_thumb_muller('sun.wav', k = 10)
foote  = audio_thumb_cf('sun.wav', k = 10)
# Out:
# Calculating features...
# Features calculated.
# Calculating SSM...
# SSM calculated.
# Calculating features...
# Features calculated.
# Calculating SSM...
# SSM calculated.

# %%
muller.ssm.visualize()

# %%
muller.thumb_time(20)
# Out:
# 0.00 0.14 0.28 0.42 0.56 0.70 0.84 0.98 1.13 1.27 1.41 1.55 1.69 1.83 1.97 2.11 2.25 2.39 2.53 2.67 2.81 2.95 3.09 3.23 3.38 3.52 3.66 3.80 3.94 4.08 4.22 4.36 4.50 4.64 4.78 4.92 5.06 5.20 5.34 5.49 5.63 5.77 5.91 6.05 6.19 6.33 6.47 6.61 6.75 6.89 7.03 7.17 7.31 7.45 7.59 7.74 7.88 8.02 8.16 8.30 8.44 8.58 8.72 8.86 9.00 9.14 9.28 9.42 9.56 9.70 9.85 9.99 10.13 10.27 10.41 10.55 10.69 10.83 10.97 11.11 11.25 11.39 11.53 11.67 11.81 11.95 12.10 12.24 12.38 12.52 12.66 12.80 12.94 13.08 13.22 13.36 13.50 13.64 13.78 13.92 14.06 14.21 14.35 14.49 14.63 14.77 14.91 15.05 15.19 15.33 15.47 15.61 15.75 15.89 16.03 16.17 16.32 16.46 16.60 16.74 16.88 17.02 17.16 17.30 17.44 17.58 17.72 17.86 18.00 18.14 18.28 18.42 18.57 18.71 18.85 18.99 19.13 19.27 19.41 19.55 19.69 19.83 19.97 20.11 20.25 20.39 20.53 20.68 20.82 20.96 21.10 21.24 21.38 21.52 21.66 21.80 21.94 22.08 22.22 22.36 22.50 22.64 22.78 22.93 23.07 23.21 23.35 23.49 23.63 23.77 23.91 24.05 24.19 24.33 24.47 24.61 24.75 24.89 25
# ...

# %%
foote.thumb_time(40)
# Out:
# The best thumbnail for this song with length 39.93 starts at time: 135.8s

# %%
muller = audio_thumb_muller('sun.wav', k = 10, t = 'tempo')
foote  = audio_thumb_cf('sun.wav', k = 10, t = 'tempo')
# Out:
# Calculating features...
# Features calculated.
# Calculating SSM...
# SSM calculated.
# Calculating features...
# Features calculated.
# Calculating SSM...
# SSM calculated.

# %%
muller.ssm.visualize()

# %%
muller.thumb_time(20)
# Out:
# 0.00 0.14 0.28 0.42 0.56 0.70 0.84 0.98 1.13 1.27 1.41 1.55 1.69 1.83 1.97 2.11 2.25 2.39 2.53 2.67 2.81 2.95 3.09 3.23 3.38 3.52 3.66 3.80 3.94 4.08 4.22 4.36 4.50 4.64 4.78 4.92 5.06 5.20 5.34 5.49 5.63 5.77 5.91 6.05 6.19 6.33 6.47 6.61 6.75 6.89 7.03 7.17 7.31 7.45 7.59 7.74 7.88 8.02 8.16 8.30 8.44 8.58 8.72 8.86 9.00 9.14 9.28 9.42 9.56 9.70 9.85 9.99 10.13 10.27 10.41 10.55 10.69 10.83 10.97 11.11 11.25 11.39 11.53 11.67 11.81 11.95 12.10 12.24 12.38 12.52 12.66 12.80 12.94 13.08 13.22 13.36 13.50 13.64 13.78 13.92 14.06 14.21 14.35 14.49 14.63 14.77 14.91 15.05 15.19 15.33 15.47 15.61 15.75 15.89 16.03 16.17 16.32 16.46 16.60 16.74 16.88 17.02 17.16 17.30 17.44 17.58 17.72 17.86 18.00 18.14 18.28 18.42 18.57 18.71 18.85 18.99 19.13 19.27 19.41 19.55 19.69 19.83 19.97 20.11 20.25 20.39 20.53 20.68 20.82 20.96 21.10 21.24 21.38 21.52 21.66 21.80 21.94 22.08 22.22 22.36 22.50 22.64 22.78 22.93 23.07 23.21 23.35 23.49 23.63 23.77 23.91 24.05 24.19 24.33 24.47 24.61 24.75 24.89 25
# ...
